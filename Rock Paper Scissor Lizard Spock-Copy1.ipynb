# %%
import random
import time
l=["ROCK","PAPER","SCISSOR","LIZARD","SPOCK"]

# %%
def play(player1,computer1):
    if player1=="PAPER" and computer1=="ROCK": 
        score[0]=score[0]+1
    elif player1=="SCISSOR" and computer1=="PAPER":  
        score[0]=score[0]+1
    elif player1=="ROCK" and computer1=="LIZARD":
        score[0]=score[0]+1
    elif player1=="LIZARD" and computer1=="SPOCK": 
        score[0]=score[0]+1
    elif player1=="SPOCK" and computer1=="SCISSOR":
        score[0]=score[0]+1
    elif player1=="SCISSOR" and computer1=="LIZARD": 
        score[0]=score[0]+1
    elif player1=="LIZARD" and computer1=="PAPER":
        score[0]=score[0]+1
    elif player1=="PAPER" and computer1=="SPOCK": 
        score[0]=score[0]+1
    elif player1=="SPOCK" and computer1=="ROCK": 
        score[0]=score[0]+1
    elif player1=="ROCK" and computer1=="SCISSOR": 
        score[0]=score[0]+1
    elif player1==computer1:
        print("Both chose same sign.")
        pass
    else:
        score[1]=score[1]+1     
    return score

# %%
def computerplay():
        player=input("Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:\n ")
        player=player.upper()
        if player not in l:
            print("Wrong choice, choose again...!!")
            computerplay()
        else:
            print("Computer is making the move...")
            time.sleep(3)
            computer=random.choice(l)
            print("You chose: ",player)
            print("Computer chose: ",computer)
            play(player,computer)
            print(choice.player1name,"'s score: ",score[0])
            print("Computer's score: ",score[1])

# %%
def player2play(player1):
            print(choice.player2name,"'s turn")
            player2=input("Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:\n ")
            player2=player2.upper()
            if player2 not in l:
                print("Wrong choice, choose again...!!")
                player2play(player1)
            else:
                print("Player 1 chose: ",player1)
                print("Player 2 chose: ",player2)
                play(player1,player2)
                print(choice.player1name,"'s score: ",score[0])
                print(choice.player2name,"'s score: ",score[1])
def player1play():
        print(choice.player1name,"'s turn")
        player1=input("Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:\n ")
        player1=player1.upper()
        if player1 not in l:
            print("Wrong choice, choose again...!!")
            player1play()
        else:
            player2play(player1)

# %%
def scores(s):
    if s[0]>s[1]:
        print('\033[1m' + choice.player1name,"wins!"+  '\033[0m')
    if s[0]<s[1]:
        print('\033[1m'+ choice.player2name,"wins!" + '\033[0m')

# %%
def again():
    again=input("Do you want play again?\n")
    if again=="YES":
        score[0]=score[1]=0
        choice()
    else:
        print('\033[1m'+ "Thanks for playing!!" + '\033[0m')

# %%
print("Welcome to the game!")
def start():
    n=int(input("Enter no. of rounds you want to play "))
    for i in range(0,n):
                if choice.choose=="computer":
                    computerplay()
                elif choice.choose=="player":
                    player1play()
    scores(score)
    again()
score=[0,0]
def choice():
    choice.choose=input("Do you want to play with computer or player?")
    if choice.choose=="computer":
        choice.player1name=input("Enter player name\n")
        choice.player2name="Computer"
        start()
    elif choice.choose=="player":
        choice.player1name=input("Enter player 1 name\n")
        choice.player2name=input("Enter player 2 name\n") 
        start()
    else:
        print("Wrong choice!\nChoose again")
        choice()
choice()
# Out:
# Welcome to the game!
# Do you want to play with computer or player?
# Wrong choice!
#  Choose again
# Do you want to play with computer or player?player
# Enter player 1 name
# shruti
# Enter player 2 name
# harsh
# Enter no. of rounds you want to play 2
# shruti 's turn
# Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:
#  spock
# harsh 's turn
# Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:
#  rock
# Player 1 chose:  SPOCK
# Player 2 chose:  ROCK
# shruti 's score:  1
# harsh 's score:  0
# shruti 's turn
# Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:
#  apsfb
# Wrong choice, choose again...!!
# shruti 's turn
# Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:
#  paper
# harsh 's turn
# Choose between ROCK, PAPER,SCISSOR,LIZARD AND SPOCK:
#  spock
# Player 1 chose:  PAPER
# Player 2 chose:  SPOCK
# shruti 's score:  2
# harsh 's score:  0
# shruti wins!
# Do you want play again?
# YES
# Do you want to play with computer or player?player
# Enter player 1 name
# ...
